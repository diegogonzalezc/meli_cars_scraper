# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
pd.set_option('display.float_format','{:,.0f}'.format)

# %%
df_antioquia=pd.read_csv('Datos_obtenidos/antioquia.csv')
valid=df_antioquia.notnull() # elimino los valores que no tiene información
df_antioquia=df_antioquia[valid.Marca]

# %%
df_antioquia
# Out:
#       Unnamed: 0          Marca    Modelo   Año     Color Tipo de combustible  \
# 0              0  Mercedes-Benz   Clase E 2,016    Blanco            Gasolina
# 1              1           Jeep  Wrangler 2,014      Rojo            Gasolina
# 2              2           Ford  Explorer 2,014     Negro            Gasolina
# 3              3         Nissan  Frontier 2,022      Gris              Diésel
# 4              4     Mitsubishi   Montero 2,004  Plateado            Gasolina
# ...          ...            ...       ...   ...       ...                 ...
# 1705        1705         Toyota     Prado 2,007      Gris            Gasolina
# 1706        1706      Chevrolet      Onix 2,022      Rojo            Gasolina
# 1707        1707         Nissan   X-Trail 2,007  Gasolina                   5
# 1708        1708        Porsche       718 2,018  Gasolina                   2
# 1709        1709         Nissan     Kicks 2,022      Azul            Gasolina
#
# ...

# %%
df_antioquia.iloc[1709,12]
# Out:
# 'https://carro.mercadolibre.com.co/MCO-937622556-nissan-versa-advance-2016-_JM#position=30&search_layout=grid&type=item&tracking_id=0792544b-be87-471f-b67c-44b8c6788860'

# %%
modelo=df_antioquia['Modelo']=='Versa'
año=df_antioquia['Año']==2016
df_antioquia[modelo&año]
# Out:
#       Unnamed: 0   Marca Modelo   Año     Color Tipo de combustible Puertas  \
# 77            77  Nissan  Versa 2,016      Gris            Gasolina       4
# 1404        1404  Nissan  Versa 2,016  Plateado            Gasolina       4
#
#      Transmisión Motor Tipo de carrocería Kilómetros      Precio  \
# 77    Automática   1.6              Sedán   71000 km  42.000.000
# 1404  Automática   1.6              Sedán   74000 km  44.500.000
#
#                                                    Link  \
# 77    https://carro.mercadolibre.com.co/MCO-93762255...
# 1404  https://carro.mercadolibre.com.co/MCO-93184703...
#
#                           Ubicación
# 77                           Itaguí
# 1404  Loma de las brujas - Envigado

# %%
df_antioquia.iloc[77,12]
# Out:
# 'https://carro.mercadolibre.com.co/MCO-937622556-nissan-versa-advance-2016-_JM#position=30&search_layout=grid&type=item&tracking_id=0792544b-be87-471f-b67c-44b8c6788860'

# %%
links=df_antioquia['Link'].unique()
links.shape
# Out:
# (96,)
